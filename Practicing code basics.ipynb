# %% [markdown]
# ## Practicing code basics (Python)
# This is a document where I can practice the basics of coding in Python for use in University courses and my own projects.

# %%
# Mandatory first step :)
print('hello world')
# Out:
# hello world

# %% [markdown]
# ### Loops

# %%
# Create a list
